# %%
#1.Write a Python program to check if the given number is a Disarium Number?
import math as m
def disarium_num():
  x=input()
  sum=0
  i=len(x)
  a=int(x) #175
  temp=a
  while a!=0:
    digit=a%10 #5
    #print(digit)
    sum=sum+m.pow(digit,i)
    #print(sum)
    a=int(a//10) #17
    #print(a)
    i=i-1
  #print(sum)
  if (int(x)==sum):
    print("Disarium Number")
  else:
    print("Not Disarium number")     


disarium_num()
# Out:
# 175
# Disarium Number

# %%
#2.Write a Python program to print all disarium numbers between 1 to 100?
def length_num(num):
  len_value=0
  while num!=0:
    len_value+=1
    num=num//10
  return len_value  

length_num(1234)
def disarium(value):
  sum=0
  temp=value
  l=length_num(value)
  while temp!=0:
    digit=temp%10
    sum=sum+(digit**l)
    temp=temp//10
    l=l-1
  return sum

resulut=0  # initilizing sum is 0
for i in range(1,101):
  result=disarium(i)

  if (result==i):
    print("The disarium number is:",i)
# Out:
# The disarium number is: 1
# The disarium number is: 2
# The disarium number is: 3
# The disarium number is: 4
# The disarium number is: 5
# The disarium number is: 6
# The disarium number is: 7
# The disarium number is: 8
# The disarium number is: 9
# The disarium number is: 89

# %%
#3.Write a Python program to check if the given number is Happy Number?
def ishappy(num):
  sum=0
  while num>0:
    digit=num%10
    sum=sum+(digit*digit)
    num=num//10
  return sum
num=int(input("Enter the number:"))    
res=num 
while (res!=1 and res!=4):
  res=ishappy(res)
if res==1:
  print("Happy number")  
else:
  print("Not happy number")
# Out:
# Enter the number:19
# Happy number

# %%
#4.Write a Python program to print all happy numbers between 1 and 100? 
def ishappy1(num):
  sum=0
  while num>0:
    digit=num%10
    sum=sum+(digit*digit)
    num=num//10
  return sum

for num in range(1,101):
  #print(num)
  res=num
  while (res!=1 and res!=4):
    res=ishappy1(res)
  if (res==1):
    print("Happy number:",num)
# Out:
# Happy number: 1
# Happy number: 7
# Happy number: 10
# Happy number: 13
# Happy number: 19
# Happy number: 23
# Happy number: 28
# Happy number: 31
# Happy number: 32
# Happy number: 44
# Happy number: 49
# Happy number: 68
# Happy number: 70
# Happy number: 79
# Happy number: 82
# Happy number: 86
# Happy number: 91
# Happy number: 94
# Happy number: 97
# Happy number: 100

# %%
#5.Write a Python program to determine whether the given number is a Harshad Number?
def Harshadnumber(num):
  sum=0
  n=num
  while (num>0):
    rem=num%10
    sum=sum+rem
    num=num//10 
  if(n%sum==0):
    print(n,"is a Harshad number") 
  else:
    print(n,"is not a Hardshad number")    
Harshadnumber(156)
# Out:
# 156 is a Harshad number

# %%
#6.Write a Python program to print all pronic numbers between 1 and 100?
import math as m
def Ispronic_number(n):
  flag=False
  for j in range(1,n+1):
    if (j*(j+1)==n):
      flag=True
      break
  return flag 
for i in range(1,101):
  if(Ispronic_number(i)):
    print(i)
# Out:
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
