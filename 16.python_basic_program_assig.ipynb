# %%
Question1. Write a function that stutters a word as if someone is struggling to read it. 
The first two letters are repeated twice with an ellipsis ... and space after each, and then the word is pronounced with a question mark ?.
Examples
stutter("incredible") ➞ "in... in... incredible?"

stutter("enthusiastic") ➞ "en... en... enthusiastic?"

stutter("outstanding") ➞ "ou... ou... outstanding?"

Hint :- Assume all input is in lower case and at least two characters long.

# %%
def stutter():
  word=input()
  pro=word[0:2] +"..."+word[0:2] +"..." + word[:] +"?"
  return pro
stutter()
# Out:
# incredible
# 'in...in...incredible?'

# %%
stutter()
# Out:
# enthusiastic
# 'en...en...enthusiastic?'

# %%
stutter()
# Out:
# outstanding
# 'ou...ou...outstanding?'

# %%
Question 2.Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.
Examples
radians_to_degrees(1) ➞ 57.3

radians_to_degrees(20) ➞ 1145.9

radians_to_degrees(50) ➞ 2864.8

# %%
import math as m
def func2(a):
  degree=a*(180/m.pi)
  return degree
func2(1)
# Out:
# 57.29577951308232

# %%
func2(20)
# Out:
# 1145.9155902616465

# %%
func2(50)
# Out:
# 2864.7889756541163

# %%
Question 3. In this challenge, establish if a given integer num is a Curzon number. If 1 plus 2 elevated to num is exactly divisible by 1 plus 2 multiplied
 by num, then num is a Curzon number.
Given a non-negative integer num, implement a function that returns True if num is a Curzon number, or False otherwise.

# %%
import math as m
def curzon():
  n=int(input("Enter the number :"))
  if n<0:
    print("enter positive number")
  else:

    powerterm=m.pow(2,n)+1
    productterm=2*n+1
    if powerterm%productterm==0:
      print("curzon number")
    else:
      print("not curzon number")  
curzon()
# Out:
# Enter the number :5
# curzon number

# %%
import math as m
def hex():
  s=int(input("Enter the side : "))
  Area=(3*m.sqrt(3)*m.pow(s,2))/2
  return Area

# %%
hex()
# Out:
# Enter the side : 1
# 2.598076211353316

# %%
hex()
# Out:
# Enter the side : 2
# 10.392304845413264

# %%
hex()
# Out:
# Enter the side : 3
# 23.382685902179844

# %%
Question 5. Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number. To convert is simple: 
((2) means base-2 and (10) means base-10) 010101001(2) = 1 + 8 + 32 + 128.
Going from right to left, the value of the most right bit is 1, now from that every bit to the left will be x2 the value, value of an 8 bit 
binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).
Examples
binary(1) ➞ "1"
# 1*1 = 1

binary(5) ➞ "101"
# 1*1 + 1*4 = 5

binary(10) ➞ "1010"
# 1*2 + 1*8 = 10

# %%
def dec_binary(n):
  if n>1:
    dec_binary(n//2)
  print(n%2,end="")

# %%
dec_binary(256)
# Out:
# 100000000

# %%
dec_binary(128)
# Out:
# 10000000

# %%
dec_binary(64)
# Out:
# 1000000

# %%
dec_binary(32)
# Out:
# 100000

# %%
dec_binary(16)
# Out:
# 10000

# %%
dec_binary(8)
# Out:
# 1000

# %%
dec_binary(4)
# Out:
# 100

# %%
dec_binary(2)
# Out:
# 10

# %%
dec_binary(1)
# Out:
# 1
